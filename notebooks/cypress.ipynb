# %%
import os
import pdfrw
import pdf_redactor

def uncompress(pages):
    for page in pages:
        for content in page.Contents:
            pdfrw.uncompress.uncompress([content])

# %%
CYPRESS_PATH = 'ignore/cypress-example.PDF'
# qpdf --stream-data=uncompress --object-streams=disable notebooks/ignore/cypress-example.PDF notebooks/ignore/cypress-example.unc.pdf
CYPRESS_PATH_UNC = 'ignore/cypress-example.unc.PDF'

ANNOT_KEY = '/Annots'
ANNOT_FIELD_KEY = '/T'
ANNOT_VAL_KEY = '/V'
ANNOT_RECT_KEY = '/Rect'
SUBTYPE_KEY = '/Subtype'
WIDGET_SUBTYPE_KEY = '/Widget'

# %%
pdf = pdfrw.PdfReader(CYPRESS_PATH)
pdf_unc = pdfrw.PdfReader(CYPRESS_PATH_UNC)

# %%
pdf.keys()
pdf_unc.keys()
# Out:
# ['/Info', '/Root', '/Size', '/ID']

# %%
uncompress(pdf.pages)

# %%
page0 = pdf.pages[0].Contents[1].stream
page1 = pdf.pages[1].Contents[1].stream
page2 = pdf.pages[1].Contents[1].stream

# %%
page0[:50]
# Out:
# 'q\nq\n0 1 -1 0 16 800 cm\nBT\n1 0 0 1 -756.57 0 Tm\n/F1'

# %% [markdown]
# ## Using pdf_redactor

# %%
data = {}
tokens = list(pdf_redactor.build_text_layer(pdf, None))

# %%
tokens[0]
# Out:
# [Token<'Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy.'>,
#  Token<'Case Details for Court Case ORANGE 15IF702186'>,
#  Token<'Defendant: '>,
#  Token<'BOWES,DANIEL,PATRICK'>,
#  Token<'Case Information'>,
#  Token<'Case Record Was Last Updated: '>,
#  Token<'09/22/2015'>,
#  Token<'Case Status: '>,
#  Token<'DISPOSED'>,
#  Token<'Microfilm Number: '>,
#  Token<'-'>,
#  Token<'Case Was Reinstated: '>,
#  Token<'-'>,
#  Token<'Jurisdiction: '>,
#  Token<'DISTRICT COURT'>,
#  Token<'Citation Number: '>,
#  Token<'8878F91'>,
#  Token<'Originating Case (OCA) or Incident'>,
#  Token<'•   Agency: '>,
#  Token<'-'>,
#  Token<'•   Number: '>,
#  Token<'-'>,
#  Token<'Process Type in District Court: '>,
#  Token<'CITATION'>,
#  Token<'Process Type in Superior Court: '>,
#  Token<'-'>,
#  Token<'Domestic Violence General Statute (G.S. 50B) Applies to'>,
#  Token<'•   Charged Offenses: '>,
#  Token<'NO'>,
#  Token<'•   Offenses Convicted in District Court: '>,
#  Token<'NO'>,
#  Token<"Crime Victim's Rights Act (G.S. 15A-830) Applies: ">,
#  Token<'NO'>,
#  Token<'Interpreter Used: '>,
#  Token<'-'>,
#  Token<'Offense Date/Time: '>,
#  Token<'05/17/2015 09:59 PM'>,
#  Token<'Case Was Issued on: '>,
#  Token<'05/17/2015'>,
#  Token<'Case Was Entered on: '>,
#  Token<'05/18/2015'>,
#  Token<'Case Was Served on: '>,
#  Token<'05/17/2015'>,
#  Token<'Court Session'>,
#  Token<'•   Date: '>,
#  Token<'07/15/2015'>,
#  Token<'•   Session: '>,
#  Token<'AM'>,
#  Token<'•   Room: '>,
#  Token<'-'>,
#  Token<'Number of Times the Case Was Continued'>,
#  Token<'•   By the Defense: '>,
#  Token<'1'>,
#  Token<'•   By the State: '>,
#  Token<'-'>,
#  Token<'•   By the Judge: '>,
#  Token<'-'>,
#  Token<'•   Because the Case Could Not Be Heard on the Scheduled Date: '>,
#  Token<'-'>,
#  Token<'Case Notes: '>,
#  Token<'-'>,
#  Token<'Case Officials'>,
#  Token<'Prosecuting Attorney'>,
#  Token<'•   Assigned on: '>,
#  Token<'07/15/2015'>,
#  Token<'•   Initials: '>,
#  Token<'JLN'>,
#  Token<'•   Name: '>,
#  Token<'NIEMAN,JEFFREY,LARKIN'>,
#  Token<'Defense Attorney'>,
#  Token<'•   Type: '>,
#  Token<'PRIVATELY RETAINED (SELF)'>,
#  Token<'•   Assigned on: '>,
#  Token<'07/15/2015'>,
#  Token<'•   Name: '>,
#  Token<'KENNEDY,KEVIN'>,
#  Token<'Arrest and Release Information'>,
#  Token<'No arrest information was recorded for this case.'>,
#  Token<'Violation of Court Orders'>,
#  Token<'Cash Bond Was Forfeited on: '>,
#  Token<'-'>,
#  Token<'Outstanding Order for Arrest Exists: '>,
#  Token<'NO'>,
#  Token<'Terms of Probation Were Violated: '>,
#  Token<'NO'>,
#  Token<'Failed to Comply with Ordered Payment within Grace'>,
#  Token<'Period: '>,
#  Token<'YES'>,
#  Token<'Order to Show Cause Exists: '>,
#  Token<'NO'>,
#  Token<'Dates Related to Missed Court Appearances'>,
#  Token<'•   Last Called And Failed on: '>,
#  Token<'-'>,
#  Token<'•   Failed to Appear Within 20 days: '>,
#  Token<'-'>,
#  Token<'•   Appeared After Failing to Appear: '>,
#  Token<'-'>,
#  Token<'Defendant'>,
#  Token<'Name: '>,
#  Token<'BOWES,DANIEL,PATRICK'>,
#  Token<'Alias Names:\t\t'>,
#  Token<'-'>,
#  Token<'Date of Birth/Estimated Age:'>,
#  Token<'09/10/1988'>,
#  Token<'Race: '>,
#  Token<'WHITE'>,
#  Token<'Driver License Information'>,
#  Token<'•   License State: '>,
#  Token<'NC'>,
#  Token<'•   Commercial License: '>,
#  Token<'NO'>,
#  Token<'Sex: '>,
#  Token<'MALE'>,
#  Token<'Address: '>,
#  Token<'1030 SUNNYVIEW CIR'>,
#  Token<'         \t\t\t\t\t\t\tMATTHEWS, NC 28105'>,
#  Token<'•   State Reciprocity: '>,
#  Token<'NO'>,
#  Token<'•   Civil Revocation Effective: '>,
#  Token<'-'>,
#  Token<'•   Civil Revocation Status: '>,
#  Token<'-'>,
#  Token<'Witnesses'>,
#  Token<'Printed on 04/02/2019 at 01:25:53 PM'>,
#  Token<'ORANGE 15IF702186'>,
#  Token<'Page 1 of'>,
#  Token<'Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy.'>,
#  Token<'Address'>,
#  Token<'Phone Numbers'>,
#  Token<'Subpoena'>,
#  Token<'Name: '>,
#  Token<'MORRISON,M,L'>,
#  Token<'Type: '>,
#  Token<'COMPLAINANT'>,
#  Token<'Officer Number: '>,
#  Token<'1529'>,
#  Token<'Agency: '>,
#  Token<'STATE HIGHWAY PATROL'>,
#  Token<'HILLSBOROUGH, NC, -'>,
#  Token<'Home: '>,
#  Token<'-'>,
#  Token<'Work: '>,
#  Token<'-'>,
#  Token<'Requested: '>,
#  Token<'-'>,
#  Token<'Issued: '>,
#  Token<'-'>,
#  Token<'Served: '>,
#  Token<'-'>,
#  Token<'Served By: '>,
#  Token<'-'>,
#  Token<'Citation Information'>,
#  Token<'Citation Number: '>,
#  Token<'8878F91'>,
#  Token<'Offense Date/Time: '>,
#  Token<'05/17/2015 09:59 PM'>,
#  Token<'State Road Number: '>,
#  Token<'I40'>,
#  Token<'Commercial Vehicle: '>,
#  Token<'NO'>,
#  Token<'Hazardous Material: '>,
#  Token<'NO'>,
#  Token<'Vehicle Type: '>,
#  Token<'2 OR 4 DOOR SEDAN (PASSENGER) CAR'>,
#  Token<'State Highway Patrol Area Number: '>,
#  Token<'01'>,
#  Token<'State Highway Patrol Troop and District: '>,
#  Token<'D7'>,
#  Token<'Accident Severity: '>,
#  Token<'NEAR ACCIDENT OR NO ACCIDENT'>,
#  Token<'Trailer Type: '>,
#  Token<'-'>,
#  Token<'License Plate: '>,
#  Token<'NC CLH4137'>,
#  Token<'Consolidation for Judgment'>,
#  Token<'No consolidation information was recorded for this case.'>,
#  Token<'Offense Record 1 of 1 (Line Number 1)\t\t\t\t  \t\t'>,
#  Token<'\t'>,
#  Token<'DISTRICT COURT (Current Jurisdiction )'>,
#  Token<'Description'>,
#  Token<'Severity'>,
#  Token<'Law'>,
#  Token<'NCAOC'>,
#  Token<'Code'>,
#  Token<'CHARGED'>,
#  Token<'SPEEDING(80 mph in a 65 mph zone)'>,
#  Token<'INFRACTION'>,
#  Token<'G.S. 20-141(B)'>,
#  Token<'4450'>,
#  Token<'ARRAIGNED'>,
#  Token<'SPEEDING(80 mph in a 65 mph zone)'>,
#  Token<'INFRACTION'>,
#  Token<'G.S. 20-141(B)'>,
#  Token<'4450'>,
#  Token<'CONVICTED'>,
#  Token<'IMPROPER EQUIP - SPEEDOMETER'>,
#  Token<'INFRACTION'>,
#  Token<'G.S. 20-123.2'>,
#  Token<'4418'>,
#  Token<'Disposed on: '>,
#  Token<'07/15/2015'>,
#  Token<'Disposition Method: '>,
#  Token<'DISPOSED BY JUDGE'>,
#  Token<'Disposition Reason: '>,
#  Token<'-'>,
#  Token<'Plea: '>,
#  Token<'RESPONSIBLE TO LESSER'>,
#  Token<'Verdict: '>,
#  Token<'RESPONSIBLE'>,
#  Token<'Sentencing Class: '>,
#  Token<'-'>,
#  Token<'Correction Reason: '>,
#  Token<'-'>,
#  Token<'Offense Record: Court Officials'>,
#  Token<'Judge: '>,
#  Token<'SCARLETT,BEVERLY,A'>,
#  Token<'\t\t\t\t'>,
#  Token<'Initials: '>,
#  Token<'BAS'>,
#  Token<'Prosecuting Attorney'>,
#  Token<'Defense Attorney'>,
#  Token<'Assigned'>,
#  Token<'on'>,
#  Token<'Initials'>,
#  Token<'Name'>,
#  Token<'Type'>,
#  Token<'Assigned'>,
#  Token<'on'>,
#  Token<'Name'>,
#  Token<'07/15/2015'>,
#  Token<'JLN'>,
#  Token<'NIEMAN,JEFFREY,L'>,
#  Token<'PRIVATELY'>,
#  Token<'RETAINED'>,
#  Token<'07/15/2015'>,
#  Token<'KENNEDY,KEVIN'>,
#  Token<'Offense Record: Violation of Court Orders'>,
#  Token<'Bond Forfeiture Was Ordered on: '>,
#  Token<'-'>,
#  Token<'Cash Bond Was Forfeited on: '>,
#  Token<'-'>,
#  Token<'Show Cause Order Issued on: '>,
#  Token<'-'>,
#  Token<'Outstanding Order for Arrest Issued on: '>,
#  Token<'-'>,
#  Token<'Terms of Probation Were Violated on: '>,
#  Token<'-'>,
#  Token<'Dates Related to Missed Court Appearances'>,
#  Token<'•   Failed to Appear (Called & Failed) on: '>,
#  Token<'-'>,
#  Token<'•   Failed to Appear Within 20 days: '>,
#  Token<'-'>,
#  Token<'•   Appeared After Failing to Appear: '>,
#  Token<'-'>,
#  Token<'Dates Related to Failing to Comply a with Court Order'>,
#  Token<'•   Failed to Comply on: '>,
#  Token<'-'>,
#  Token<'•   Failed to Comply with Ordered Payment within Grace Period on:'>,
#  Token<'08/10/2015'>,
#  Token<'•   Complied with Ordered Payments after Failing to Comply on:'>,
#  Token<'09/21/2015'>,
#  Token<'Community Service License Revocation on: '>,
#  Token<'-'>,
#  Token<'Community Service License Revocation Compliance on: '>,
#  Token<'-'>,
#  Token<'Offense Record:  Transfers or Appeals'>,
#  Token<'No appeals or transfers were recorded for this offense.'>,
#  Token<'Offense Record: Special Conditions'>,
#  Token<'No special conditions were recorded for this offense.'>,
#  Token<'Offense Record: Sentence'>,
#  Token<'No sentence information was recorded for this offense.'>,
#  Token<'Offense Record: Probation'>,
#  Token<'No probation information was recorded for this offense.'>,
#  Token<'Printed on 04/02/2019 at 01:25:53 PM'>,
#  Token<'ORANGE 15IF702186'>,
#  Token<'Page 2 of'>,
#  Token<'Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy.'>,
#  Token<'Offense Record: Monies'>,
#  Token<'Monies Paid Status: '>,
#  Token<'DEFENDANT HAS COMPLIED WITH FINE OR COST'>,
#  Token<'Date Monies To Be Paid: '>,
#  Token<'-'>,
#  Token<'Fine'>,
#  Token<'Amount'>,
#  Token<'Status'>,
#  Token<'$25.00'>,
#  Token<'ORDERED'>,
#  Token<'Restitution'>,
#  Token<'Total Restitution Amount: '>,
#  Token<'-'>,
#  Token<'Status:  '>,
#  Token<'-'>,
#  Token<'Remarks:  '>,
#  Token<'-'>,
#  Token<'Payee'>,
#  Token<'Amount'>,
#  Token<'Court Cases of Defendants Responsible for'>,
#  Token<'Paying Restitution Jointly and Severally'>,
#  Token<'Status'>,
#  Token<'-'>,
#  Token<'-'>,
#  Token<'-'>,
#  Token<'-'>,
#  Token<'Detailed Court Costs'>,
#  Token<'Total Court Cost Amount: '>,
#  Token<'$288.00'>,
#  Token<'Waive Court Costs: '>,
#  Token<'NOT WAIVED'>,
#  Token<'Cost Category'>,
#  Token<'Amount'>,
#  Token<'Status'>,
#  Token<'GCJF DISTRICT'>,
#  Token<'$127.05'>,
#  Token<'ORDERED'>,
#  Token<'GCJF DISTRICT LAA'>,
#  Token<'$2.45'>,
#  Token<'ORDERED'>,
#  Token<'LEOB RF'>,
#  Token<'$7.50'>,
#  Token<'ORDERED'>,
#  Token<'LE CERT TRAINING DISTRICT'>,
#  Token<'$2.00'>,
#  Token<'ORDERED'>,
#  Token<'TELEPHONE FEE DISTRICT'>,
#  Token<'$4.00'>,
#  Token<'ORDERED'>,
#  Token<'MCF FEE'>,
#  Token<'$18.00'>,
#  Token<'ORDERED'>,
#  Token<'CHAPTER 20 VIOLATION FEE DISTRICT'>,
#  Token<'$10.00'>,
#  Token<'ORDERED'>,
#  Token<'SERVICE FEE'>,
#  Token<'$5.00'>,
#  Token<'ORDERED'>,
#  Token<'FACILITIES FEE DISTRICT'>,
#  Token<'$12.00'>,
#  Token<'ORDERED'>,
#  Token<'IMPROPER EQUIPMENT FEE DISTRICT'>,
#  Token<'$50.00'>,
#  Token<'ORDERED'>,
#  Token<'FTC 20DF FEE DISTRICT'>,
#  Token<'$50.00'>,
#  Token<'ORDERED'>,
#  Token<'DMV Notification Events'>,
#  Token<'Event Date'>,
#  Token<'Event Name'>,
#  Token<'Method of Notification to'>,
#  Token<'DMV'>,
#  Token<'Jurisdiction'>,
#  Token<'Offense #'>,
#  Token<'09/22/2015'>,
#  Token<'COMPLIANCE TO FAILURE TO'>,
#  Token<'COMPLY'>,
#  Token<'SENT ELECTRONICALLY'>,
#  Token<'DISTRICT COURT'>,
#  Token<'-'>,
#  Token<'08/10/2015'>,
#  Token<'FAILURE TO COMPLY'>,
#  Token<'SENT ELECTRONICALLY'>,
#  Token<'DISTRICT COURT'>,
#  Token<'-'>,
#  Token<'07/15/2015'>,
#  Token<'CONVICTION'>,
#  Token<'SENT ELECTRONICALLY'>,
#  Token<'DISTRICT COURT'>,
#  Token<'-'>,
#  Token<'Case Event History'>,
#  Token<'No case history events were recorded for this case.'>,
#  Token<'Disclaimer'>,
#  Token<'This document was generated using a North Carolina Administrative Office of the Courts website. The document is intended to be used as a'>,
#  Token<'resource to determine the general status of historical and in-process court cases. This information is not the official record of the court. As'>,
#  Token<"such, it should only be used to gain a general understanding of a case's history and disposition. Accordingly, the North Carolina Administrative">,
#  Token<'Office of the Courts, the office of the Clerk of Superior Court, their officials and employees are not responsible or liable for any loss,'>,
#  Token<'consequence, or damage resulting directly or indirectly from use of the information.'>,
#  Token<'Printed on 04/02/2019 at 01:25:53 PM'>,
#  Token<'ORANGE 15IF702186'>,
#  Token<'Page 3 of'>]
