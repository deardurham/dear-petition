# %% [markdown]
# # Cypress PDF - Text Extraction Exploration
#
# Code for Durham

# %%
import os
import re
import pdfrw
import pdf_redactor
import pprint

import pdfminer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-6d19e7b7a1f2> in <module>()
#       2 import re
#       3 import pdfrw
# ----> 4 import pdf_redactor
#       5 import pprint
#       6
#
# ModuleNotFoundError: No module named 'pdf_redactor'

# %%
def uncompress(pages):
    """Text content must be uncompressed before reading"""
    for page in pages:
        for content in page.Contents:
            pdfrw.uncompress.uncompress([content])

# %%
# Path to original example Cypress PDF
CYPRESS_PATH = 'ignore/cypress-example.PDF'

# %%
# Path to externally uncompressed version of Cypress PDF using:
#   qpdf --stream-data=uncompress --object-streams=disable notebooks/ignore/cypress-example.PDF notebooks/ignore/cypress-example.unc.pdf
CYPRESS_PATH_UNC = 'ignore/cypress-example.unc.PDF'

# %%
pdf = pdfrw.PdfReader(CYPRESS_PATH)
pdf_unc = pdfrw.PdfReader(CYPRESS_PATH_UNC)
uncompress(pdf.pages)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/workspace/anaconda3/lib/python3.7/site-packages/pdfrw/pdfreader.py in __init__(self, fname, fdata, decompress, decrypt, password, disable_gc, verbose)
#     567                     try:
# --> 568                         f = open(fname, 'rb')
#     569                         fdata = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ignore/cypress-example.PDF'
#
# During handling of the above exception, another exception occurred:
#
# PdfParseError                             Traceback (most recent call last)
# <ipython-input-13-fa6792e381ea> in <module>()
# ----> 1 pdf = pdfrw.PdfReader(CYPRESS_PATH)
#       2 pdf_unc = pdfrw.PdfReader(CYPRESS_PATH_UNC)
#       3 uncompress(pdf.pages)
#
# ~/workspace/anaconda3/lib/python3.7/site-packages/pdfrw/pdfreader.py in __init__(self, fname, fdata, decompress, decrypt, password, disable_gc, verbose)
#     571                     except IOError:
#     572                         raise PdfParseError('Could not read PDF file %s' %
# --> 573                                             fname)
#     574
#     575             assert fdata is not None
#
# PdfParseError: Could not read PDF file ignore/cypress-example.PDF

# %%
page0 = pdf.pages[0].Contents[1].stream
page1 = pdf.pages[1].Contents[1].stream
page2 = pdf.pages[1].Contents[1].stream

# %%
page0[:2000]
# Out:
# "q\nq\n0 1 -1 0 16 800 cm\nBT\n1 0 0 1 -756.57 0 Tm\n/F1 12 Tf\n0.45 g\n(Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy.)Tj\n0 g\nET\nQ\nQ\nq\nBT\n28 771 Td\n0 -66.5 Td\nET\nQ\nq\n1.5 w\n28 747 m\n600 747 l\nS\nQ\nq\n1.2 w\n28 714 m\n600 714 l\nS\nQ\nq\nQ\nq\n2 J\n0 G\nQ\nq 220 0 0 17.5 28 753.5 cm /img1 Do Q\nBT\n1 0 0 1 28 753.5 Tm\n220 0 Td\n-220 0 Td\nET\nq 132.5 0 0 17.5 469.5 753.5 cm /img3 Do Q\nBT\n1 0 0 1 469.5 753.5 Tm\n132.5 0 Td\n-132.5 0 Td\nET\nBT\n1 0 0 1 150.84 732.5 Tm\n/F1 14 Tf\n(Case Details for Court Case ORANGE 15IF702186)Tj\nET\nBT\n1 0 0 1 208.65 716.5 Tm\n/F1 12 Tf\n(Defendant: )Tj\n/F2 12 Tf\n(BOWES,DANIEL,PATRICK)Tj\nET\nq\n0.82353 0.82353 0.82353 rg\n28 696 574 16 re\nf\nQ\nq\n2 J\n0 G\nQ\nBT\n1 0 0 1 30 698 Tm\n/F1 12 Tf\n(Case Information)Tj\nET\nq\nQ\nq\n2 J\n0 G\nQ\nBT\n1 0 0 1 30 681 Tm\n/F1 9 Tf\n(Case Record Was Last Updated: )Tj\n/F2 9 Tf\n(09/22/2015)Tj\nET\nBT\n1 0 0 1 30 668 Tm\n/F1 9 Tf\n(Case Status: )Tj\n/F2 9 Tf\n(DISPOSED)Tj\nET\nBT\n1 0 0 1 30 655 Tm\n/F1 9 Tf\n(Microfilm Number: )Tj\n/F2 9 Tf\n(-)Tj\nET\nBT\n1 0 0 1 30 642 Tm\n/F1 9 Tf\n(Case Was Reinstated: )Tj\n/F2 9 Tf\n(-)Tj\nET\nBT\n1 0 0 1 30 629 Tm\n/F1 9 Tf\n(Jurisdiction: )Tj\n/F2 9 Tf\n(DISTRICT COURT)Tj\nET\nBT\n1 0 0 1 30 616 Tm\n/F1 9 Tf\n(Citation Number: )Tj\n/F2 9 Tf\n(8878F91)Tj\nET\nBT\n1 0 0 1 30 603 Tm\n/F1 9 Tf\n(Originating Case \\(OCA\\) or Incident)Tj\nET\nBT\n1 0 0 1 30 590 Tm\n/F1 9 Tf\n(\x95   Agency: )Tj\n/F2 9 Tf\n(-)Tj\nET\nBT\n1 0 0 1 30 577 Tm\n/F1 9 Tf\n(\x95   Number: )Tj\n/F2 9 Tf\n(-)Tj\nET\nBT\n1 0 0 1 30 560 Tm\n/F1 9 Tf\n(Process Type in District Court: )Tj\n/F2 9 Tf\n(CITATION)Tj\nET\nBT\n1 0 0 1 30 547 Tm\n/F1 9 Tf\n(Process Type in Superior Court: )Tj\n/F2 9 Tf\n(-)Tj\nET\nBT\n1 0 0 1 30 530 Tm\n/F1 9 Tf\n(Domestic Violence General Statute \\(G.S. 50B\\) Applies to)Tj\nET\nBT\n1 0 0 1 30 517 Tm\n/F1 9 Tf\n(\x95   Charged Offenses: )Tj\n/F2 9 Tf\n(NO)Tj\nET\nBT\n1 0 0 1 30 504 Tm\n/F1 9 Tf\n(\x95   Offenses Convicted in District Court: )Tj\n/F2 9 Tf\n(NO)Tj\nET\nBT\n1 0 0 1 30 491 Tm\n/F1 9 Tf\n(Crime Victim's Rights Act \\(G.S. "

# %% [markdown]
# ## Using pdf_redactor

# %%
data = {}
tokens = list(pdf_redactor.build_text_layer(pdf, None))

# %%
tokens[0][:20]
# Out:
# [Token<'Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy. ~ Not a certified copy.'>,
#  Token<'Case Details for Court Case ORANGE 15IF702186'>,
#  Token<'Defendant: '>,
#  Token<'BOWES,DANIEL,PATRICK'>,
#  Token<'Case Information'>,
#  Token<'Case Record Was Last Updated: '>,
#  Token<'09/22/2015'>,
#  Token<'Case Status: '>,
#  Token<'DISPOSED'>,
#  Token<'Microfilm Number: '>,
#  Token<'-'>,
#  Token<'Case Was Reinstated: '>,
#  Token<'-'>,
#  Token<'Jurisdiction: '>,
#  Token<'DISTRICT COURT'>,
#  Token<'Citation Number: '>,
#  Token<'8878F91'>,
#  Token<'Originating Case (OCA) or Incident'>,
#  Token<'•   Agency: '>,
#  Token<'-'>]

# %% [markdown]
# ## Using manual text searching w/ RegEx

# %%
data = {}

# %%
# DEFENDANT
# Text: (Defendant: )Tj\n/F2 12 Tf\n(BOWES,DANIEL,PATRICK)Tj\n
defendant_re = r'\(Defendant: \)Tj\n/F2 12 Tf\n\(([\w,]+)\)Tj\n'
match = re.search(defendant_re, page0)
data['defendant'] = match.group(1)

# %%
# CASE STATUS
# Text: (Case Status: )Tj\n/F2 9 Tf\n(DISPOSED)Tj\n
case_status_re = r'\(Case Status: \)Tj\n/F2 9 Tf\n\(([\w,]+)\)Tj\n'
match = re.search(case_status_re, page0)
data['case_status'] = match.group(1)

# %%
# DATE OF BIRTH
# Text: (Date of Birth/Estimated Age:)Tj\nET\nBT\n1 0 0 1 30 172 Tm\n/F2 9 Tf\n(09/10/1988)Tj\n
dob_re = r'\(Date of Birth/Estimated Age:\)Tj\nET\nBT\n1 0 0 1 30 172 Tm\n/F2 9 Tf\n\(([\w/]+)\)Tj\n'
match = re.search(dob_re, page0)
data['dob'] = match.group(1)

# %%
data
# Out:
# {'defendant': 'BOWES,DANIEL,PATRICK',
#  'case_status': 'DISPOSED',
#  'dob': '09/10/1988'}

# %% [markdown]
# ## pdfminer

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter, HTMLConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
pdf_text = convert_pdf_to_txt(CYPRESS_PATH)
pdf_text[:2000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d088c249277b> in <module>()
# ----> 1 pdf_text = convert_pdf_to_txt(CYPRESS_PATH)
#       2 pdf_text[:2000]
#
# NameError: name 'CYPRESS_PATH' is not defined

# %%
miner_data={}

# %%
# COUNTY AND FILE NO.
# Text: Case Details for Court Case ORANGE 15IF702186
case_summary_re = r'Case Details for Court Case (.+) (\w+)'
match = re.search(case_summary_re,pdf_text)
miner_data['county']=match.group(1)
miner_data['file_no']=match.group(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ea60fda0de12> in <module>()
#       2 # Text: Case Details for Court Case ORANGE 15IF702186
#       3 case_summary_re = r'Case Details for Court Case (.+) (\w+)'
# ----> 4 match = re.search(case_summary_re,pdf_text)
#       5 miner_data['county']=match.group(1)
#       6 miner_data['file_no']=match.group(2)
#
# NameError: name 'pdf_text' is not defined

# %%
# DEFENDANT
# Text: Defendant: BOWES,DANIEL,PATRICK
defendant_re = r'Defendant: ([\w,]+)'
match = re.search(defendant_re, pdf_text)
miner_data['defendant'] = match.group(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-39c857f64b3b> in <module>()
#       2 # Text: Defendant: BOWES,DANIEL,PATRICK
#       3 defendant_re = r'Defendant: ([\w,]+)'
# ----> 4 match = re.search(defendant_re, pdf_text)
#       5 miner_data['defendant'] = match.group(1)
#
# NameError: name 're' is not defined

# %%
# OFFENSE DATE
# Text: Offense Date/Time: 05/17/2015 09:59 PM
datetime_re = r'Offense Date/Time: (.+) \d'
match = re.search(datetime_re, pdf_text)
miner_data['offense_date'] = match.group(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5e7119d3f376> in <module>()
#       2 # Text: Offense Date/Time: 05/17/2015 09:59 PM
#       3 datetime_re = r'Offense Date/Time: (.+) \d'
# ----> 4 match = re.search(datetime_re, pdf_text)
#       5 miner_data['offense_date'] = match.group(1)
#
# NameError: name 're' is not defined

# %%
# DATE OF BIRTH
# Text: Date of Birth/Estimated Age:\n 09/10/1988
dob_re = r'Date of Birth/Estimated Age:\n(.+)'
match = re.search(dob_re, pdf_text)
miner_data['date_of_birth'] = match.group(1)

# %%
# RACE
# Text: Race: WHITE
race_re = r'Race: (.+)'
match = re.search(race_re,pdf_text)
miner_data['race'] = match.group(1)

# %%
# SEX
# Text: Sex: MALE
sex_re = r'Sex: (.+)'
match = re.search(sex_re,pdf_text)
miner_data['sex'] = match.group(1)

# %%
# OFFENSE DESCRIPTION
#Text: CHARGED\nSPEEDING(80 mph in a 65 mph zone)
description_re = r'CHARGED\n(.+)\n'
match = re.search(description_re,pdf_text)
miner_data['offense_description'] = match.group(1)

# %%
# VERDICT
#Text: Verdict: RESPONSIBLE
verdict_re = r'Verdict: (\w+)'
match = re.search(verdict_re,pdf_text)
miner_data['verdict'] = match.group(1)

# %%
# DISPOSED
#Text: Disposed on: 07/15/2015
disposed_re = r'Disposed on: (.+)'
match = re.search(disposed_re,pdf_text)
miner_data['disposed_on'] = match.group(1)

# %%
miner_data
# Out:
# {'defendant': 'BOWES,DANIEL,PATRICK'}

# %%
! cat ../../petition.txt
# Out:
# .
#
# y
# p
# o
# c
# d
# e
#
#
#
# i
# f
# i
# t
# r
# e
# c
# a
#
#
#
#
# t
# o
# N
# ~
#
#
#
#
# .
#
#
#
# y
# p
# o
# c
# d
# e
# i
# f
# i
# t
# r
# e
# c
# a
#
#
#
#
# t
# o
# N
# ~
#
#
#
#
# .
#
#
#
# y
# p
# o
# c
# d
# e
# i
# f
# i
# t
# r
# e
# c
#
# a
#
# t
# o
# N
# ~
#
#
#
#
# .
# y
# p
# o
# c
#
# d
# e
# i
# f
# i
# t
# r
# e
# c
#
# a
#
# t
# o
# N
# ~
#
#
#
#
# .
# y
# p
# o
# c
#
# d
# e
#
# i
# f
# i
# t
# r
# e
# c
#
#
#
# a
#
#
# t
# o
# N
# ~
#
#
#
#
# .
#
# y
# p
# o
# c
# d
# e
#
#
#
# i
# f
# i
# t
# r
# e
# c
#
#
#
# a
#
# t
# o
# N
#
# Case Details for Court Case ORANGE 15IF702186
#
# Defendant: BOWES,DANIEL,PATRICK
#
# Case Information
# Case Record Was Last Updated: 09/22/2015
# Case Status: DISPOSED
# Microfilm Number: -
# Case Was Reinstated: -
# Jurisdiction: DISTRICT COURT
# Citation Number: 8878F91
# Originating Case (OCA) or Incident
# •   Agency: -
# •   Number: -
#
# Process Type in District Court: CITATION
# Process Type in Superior Court: -
#
# Domestic Violence General Statute (G.S. 50B) Applies to
# •   Charged Offenses: NO
# •   Offenses Convicted in District Court: NO
# Crime Victim's Rights Act (G.S. 15A-830) Applies: NO
#
# Interpreter Used: -
# Case Notes: -
# Case Officials
# Prosecuting Attorney
# •   Assigned on: 07/15/2015
# •   Initials: JLN
# •   Name: NIEMAN,JEFFREY,LARKIN
# Arrest and Release Information
# No arrest information was recorded for this case.
# Violation of Court Orders
#
# Cash Bond Was Forfeited on: -
# Outstanding Order for Arrest Exists: NO
# Terms of Probation Were Violated: NO
# Failed to Comply with Ordered Payment within Grace
# Period: YES
# Order to Show Cause Exists: NO
# Defendant
# Name: BOWES,DANIEL,PATRICK
# Alias Names:(cid:9)
# Date of Birth/Estimated Age:
# 09/10/1988
# Race: WHITE
# Sex: MALE
# Address: 1030 SUNNYVIEW CIR
#          (cid:9)
# Witnesses
#
# (cid:9)MATTHEWS, NC 28105
#
# (cid:9)-
#
# Offense Date/Time: 05/17/2015 09:59 PM
# Case Was Issued on: 05/17/2015
# Case Was Entered on: 05/18/2015
# Case Was Served on: 05/17/2015
#
# Court Session
# •   Date: 07/15/2015
# •   Session: AM
# •   Room: -
#
# Number of Times the Case Was Continued
# •   By the Defense: 1
# •   By the State: -
# •   By the Judge: -
# •   Because the Case Could Not Be Heard on the Scheduled Date: -
#
# Defense Attorney
# •   Type: PRIVATELY RETAINED (SELF)
# •   Assigned on: 07/15/2015
# •   Name: KENNEDY,KEVIN
#
# Dates Related to Missed Court Appearances
# •   Last Called And Failed on: -
# •   Failed to Appear Within 20 days: -
# •   Appeared After Failing to Appear: -
#
# Driver License Information
# •   License State: NC
# •   Commercial License: NO
# •   State Reciprocity: NO
# •   Civil Revocation Effective: -
# •   Civil Revocation Status: -
#
# Printed on 04/02/2019 at 01:25:53 PM
#
# ORANGE 15IF702186
#
# Page 1 of
#
# 3(cid:9)
# (cid:9)
# (cid:9)
# (cid:9)
# (cid:9)
# Address
#
# Phone Numbers
#
# Subpoena
#
# HILLSBOROUGH, NC, -
#
# Home: -
# Work: -
#
# Requested: -
# Issued: -
# Served: -
# Served By: -
#
# Commercial Vehicle: NO
# Hazardous Material: NO
# Vehicle Type: 2 OR 4 DOOR SEDAN (PASSENGER) CAR
# Trailer Type: -
# License Plate: NC CLH4137
#
# (cid:9)DISTRICT COURT (Current Jurisdiction )
#
# Severity
#
# Law
#
# INFRACTION
# INFRACTION
# INFRACTION
#
# G.S. 20-141(B)
# G.S. 20-141(B)
# G.S. 20-123.2
#
# NCAOC
# Code
# 4450
# 4450
# 4418
#
# Plea: RESPONSIBLE TO LESSER
# Verdict: RESPONSIBLE
# Sentencing Class: -
#
# Defense Attorney
#
# Type
#
# Assigned
#
# on
#
# Name
#
# PRIVATELY
# RETAINED
#
# 07/15/2015 KENNEDY,KEVIN
#
# Outstanding Order for Arrest Issued on: -
# Terms of Probation Were Violated on: -
#
# Dates Related to Failing to Comply a with Court Order
# •   Failed to Comply on: -
# •   Failed to Comply with Ordered Payment within Grace Period on:
# 08/10/2015
# •   Complied with Ordered Payments after Failing to Comply on:
# 09/21/2015
# Community Service License Revocation Compliance on: -
#
# .
#
# y
# p
# o
# c
# d
# e
#
#
#
# i
# f
# i
# t
# r
# e
# c
# a
#
#
#
#
# t
# o
# N
# ~
#
#
#
#
# .
#
#
#
# y
# p
# o
# c
# d
# e
# i
# f
# i
# t
# r
# e
# c
# a
#
#
#
#
# t
# o
# N
# ~
#
#
#
#
# .
#
#
#
# y
# p
# o
# c
# d
# e
# i
# f
# i
# t
# r
# e
# c
#
# a
#
# t
# o
# N
# ~
#
#
#
#
# .
# y
# p
# o
# c
#
# d
# e
# i
# f
# i
# t
# r
# e
# c
#
# a
#
# t
# o
# N
# ~
#
#
#
#
# .
# y
# p
# o
# c
#
# d
# e
#
# i
# f
# i
# t
# r
# e
# c
#
#
#
# a
#
#
# t
# o
# N
# ~
#
#
#
#
# .
#
# y
# p
# o
# c
# d
# e
#
#
#
# i
# f
# i
# t
# r
# e
# c
#
#
#
# a
#
# t
# o
# N
#
# Name: MORRISON,M,L
# Type: COMPLAINANT
# Officer Number: 1529
# Agency: STATE HIGHWAY PATROL
# Citation Information
# Citation Number: 8878F91
# Offense Date/Time: 05/17/2015 09:59 PM
# State Road Number: I40
# State Highway Patrol Area Number: 01
# State Highway Patrol Troop and District: D7
# Accident Severity: NEAR ACCIDENT OR NO ACCIDENT
# Consolidation for Judgment
# No consolidation information was recorded for this case.
# Offense Record 1 of 1 (Line Number 1)(cid:9)
# (cid:9)  (cid:9)
# Description
#
# CHARGED
# SPEEDING(80 mph in a 65 mph zone)
# ARRAIGNED SPEEDING(80 mph in a 65 mph zone)
# CONVICTED IMPROPER EQUIP - SPEEDOMETER
# Disposed on: 07/15/2015
# Disposition Method: DISPOSED BY JUDGE
# Disposition Reason: -
# Correction Reason: -
#
# Offense Record: Court Officials
# Judge: SCARLETT,BEVERLY,A(cid:9)
# Prosecuting Attorney
# Assigned
# Initials
#
# on
#
# (cid:9)Initials: BAS
#
# Name
#
# 07/15/2015 JLN
#
# NIEMAN,JEFFREY,L
#
# Offense Record: Violation of Court Orders
#
# Bond Forfeiture Was Ordered on: -
# Cash Bond Was Forfeited on: -
# Show Cause Order Issued on: -
#
# Dates Related to Missed Court Appearances
# •   Failed to Appear (Called & Failed) on: -
# •   Failed to Appear Within 20 days: -
# •   Appeared After Failing to Appear: -
#
# Community Service License Revocation on: -
#
# Offense Record:  Transfers or Appeals
#
# No appeals or transfers were recorded for this offense.
# Offense Record: Special Conditions
#
# No special conditions were recorded for this offense.
# Offense Record: Sentence
#
# No sentence information was recorded for this offense.
# Offense Record: Probation
#
# No probation information was recorded for this offense.
#
# Printed on 04/02/2019 at 01:25:53 PM
#
# ORANGE 15IF702186
#
# Page 2 of
#
# 3(cid:9)
# (cid:9)
# (cid:9)
# (cid:9)
# (cid:9)
# .
#
# y
# p
# o
# c
# d
# e
#
#
#
# i
# f
# i
# t
# r
# e
# c
# a
#
#
#
#
# t
# o
# N
# ~
#
#
#
#
# .
#
#
#
# y
# p
# o
# c
# d
# e
# i
# f
# i
# t
# r
# e
# c
# a
#
#
#
#
# t
# o
# N
# ~
#
#
#
#
# .
#
#
#
# y
# p
# o
# c
# d
# e
# i
# f
# i
# t
# r
# e
# c
#
# a
#
# t
# o
# N
# ~
#
#
#
#
# .
# y
# p
# o
# c
#
# d
# e
# i
# f
# i
# t
# r
# e
# c
#
# a
#
# t
# o
# N
# ~
#
#
#
#
# .
# y
# p
# o
# c
#
# d
# e
#
# i
# f
# i
# t
# r
# e
# c
#
#
#
# a
#
#
# t
# o
# N
# ~
#
#
#
#
# .
#
# y
# p
# o
# c
# d
# e
#
#
#
# i
# f
# i
# t
# r
# e
# c
#
#
#
# a
#
# t
# o
# N
#
# Offense Record: Monies
#
# Monies Paid Status: DEFENDANT HAS COMPLIED WITH FINE OR COST
# Date Monies To Be Paid: -
#
# Fine
#
# Amount
#
# ORDERED
#
# $25.00
# Restitution
# Total Restitution Amount: -
# Status:  -
# Remarks:  -
#
# Payee
#
# Amount
#
# -
# Detailed Court Costs
# Total Court Cost Amount: $288.00
# Waive Court Costs: NOT WAIVED
#
# -
#
# Status
#
# Court Cases of Defendants Responsible for
#
# Paying Restitution Jointly and Severally
#
# Status
#
# -
#
# -
#
# Cost Category
#
# Amount
#
# Status
#
# GCJF DISTRICT
# GCJF DISTRICT LAA
# LEOB RF
# LE CERT TRAINING DISTRICT
# TELEPHONE FEE DISTRICT
# MCF FEE
# CHAPTER 20 VIOLATION FEE DISTRICT
# SERVICE FEE
# FACILITIES FEE DISTRICT
# IMPROPER EQUIPMENT FEE DISTRICT
# FTC 20DF FEE DISTRICT
# DMV Notification Events
#
# Event Date
#
# Event Name
#
# $127.05
# $2.45
# $7.50
# $2.00
# $4.00
# $18.00
# $10.00
# $5.00
# $12.00
# $50.00
# $50.00
#
# ORDERED
# ORDERED
# ORDERED
# ORDERED
# ORDERED
# ORDERED
# ORDERED
# ORDERED
# ORDERED
# ORDERED
# ORDERED
#
# Method of Notification to
#
# DMV
#
# Jurisdiction
#
# Offense #
#
# SENT ELECTRONICALLY
#
# DISTRICT COURT
#
# -
#
# 09/22/2015
#
# COMPLIANCE TO FAILURE TO
# COMPLY
# FAILURE TO COMPLY
# CONVICTION
#
# SENT ELECTRONICALLY
# SENT ELECTRONICALLY
#
# 08/10/2015
# 07/15/2015
# Case Event History
# No case history events were recorded for this case.
# Disclaimer
# This document was generated using a North Carolina Administrative Office of the Courts website. The document is intended to be used as a
# resource to determine the general status of historical and in-process court cases. This information is not the official record of the court. As
# such, it should only be used to gain a general understanding of a case's history and disposition. Accordingly, the North Carolina Administrative
# Office of the Courts, the office of the Clerk of Superior Court, their officials and employees are not responsible or liable for any loss,
# consequence, or damage resulting directly or indirectly from use of the information.
#
# DISTRICT COURT
# DISTRICT COURT
#
# -
# -
#
# Printed on 04/02/2019 at 01:25:53 PM
#
# ORANGE 15IF702186
#
# Page 3 of
#
# 3
